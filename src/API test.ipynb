# %% [markdown]
# ## Google Books Data

# %%
import requests
import os

# %%
url = 'https://www.googleapis.com/books/v1/volumes'
#get the response from the endpoint URL
response = requests.get(url)

# %%
params = {'q' : 'Machine Learning'}

# %%
response =requests.get(url, params=params)
response.json()['items']
# Out:
# [{'kind': 'books#volume',
#   'id': 'omivDQAAQBAJ',
#   'etag': 'Y26IFKoOc38',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/omivDQAAQBAJ',
#   'volumeInfo': {'title': 'Deep Learning',
#    'authors': ['Ian Goodfellow', 'Yoshua Bengio', 'Aaron Courville'],
#    'publisher': 'MIT Press',
#    'publishedDate': '2016-11-10',
# ...

# %%
#get the list of the books in the response 
books = response.json()['items']
total = 0
for book in books:
    title = book['volumeInfo']['title']
    num_pages = book['volumeInfo']['pageCount']
    total += num_pages
    if not title:
        print('No title found')

#avrage number of pages for ML books 
avrage = total/len(books)
print(avrage)
# Out:
# 538.8

# %% [markdown]
# ## Giphy

# %%
url = 'https://api.giphy.com/v1/gifs/trending'

# %%
params = {
    'api_key': os.environ['API_KEY'],
    'limit': 5
}

# %%
response = requests.get(
    url,
    params=params,
)

# %%
if response.status_code == 200:
    response.json()
else:
    print('Something went wrong!')
# Out:
# {'data': [{'type': 'gif', 'id': 'tnShYQPFMiR2qlCcwV', 'url': 'https://giphy.com/gifs/emmys-75th-emmys-tnShYQPFMiR2qlCcwV', 'slug': 'emmys-75th-emmys-tnShYQPFMiR2qlCcwV', 'bitly_gif_url': 'https://gph.is/g/ZyBy3mL', 'bitly_url': 'https://gph.is/g/ZyBy3mL', 'embed_url': 'https://giphy.com/embed/tnShYQPFMiR2qlCcwV', 'username': 'emmys', 'source': '', 'title': '75Th Emmys GIF by Emmys', 'rating': 'g', 'content_url': '', 'source_tld': '', 'source_post_url': '', 'is_sticker': 0, 'import_datetime': '2024-01-16 02:41:26', 'trending_datetime': '2024-01-21 18:46:06', 'images': {'original': {'height': '272', 'width': '480', 'size': '902183', 'url': 'https://media1.giphy.com/media/tnShYQPFMiR2qlCcwV/giphy.gif?cid=b082a809dbxmf8dqbieuop2ud8u7mgbeujsumf5uoon1mtcp&ep=v1_gifs_trending&rid=giphy.gif&ct=g', 'mp4_size': '204518', 'mp4': 'https://media1.giphy.com/media/tnShYQPFMiR2qlCcwV/giphy.mp4?cid=b082a809dbxmf8dqbieuop2ud8u7mgbeujsumf5uoon1mtcp&ep=v1_gifs_trending&rid=giphy.mp4&ct=g', 'webp_size': 
# ...

# %%
url = "https://api.exchangerate-api.com/v4/latest/USD"

# %%
response =requests.get(url)

# %%
list(response.json()['rates'].keys())
# Out:
# ['USD',
#  'AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BIF',
#  'BMD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYN',
#  'BZD',
#  'CAD',
#  'CDF',
#  'CHF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CUP',
#  'CVE',
#  'CZK',
#  'DJF',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ERN',
#  'ETB',
#  'EUR',
#  'FJD',
#  'FKP',
#  'FOK',
#  'GBP',
#  'GEL',
#  'GGP',
#  'GHS',
#  'GIP',
#  'GMD',
#  'GNF',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HTG',
#  'HUF',
#  'IDR',
#  'ILS',
#  'IMP',
#  'INR',
#  'IQD',
#  'IRR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KID',
#  'KMF',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LAK',
#  'LBP',
#  'LKR',
#  'LRD',
#  'LSL',
#  'LYD',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MRU',
#  'MUR',
#  'MVR',
#  'MWK',
#  'MXN',
#  'MYR',
# ...
